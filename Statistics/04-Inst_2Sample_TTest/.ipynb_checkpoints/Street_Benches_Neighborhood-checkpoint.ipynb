# %%
# Dependencies
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import math

# %%
# Generate "Simulated" Data
benches_city_1 = stats.poisson.rvs(loc=0, mu=4, size=52)
benches_city_2 = stats.poisson.rvs(loc=0, mu=2, size=48)

print(benches_city_1.mean())
print(benches_city_2.mean())
# Out:
# 3.51923076923
# 1.85416666667

# %%
# Plot the Data
plt.scatter(np.arange(0, len(coffee_white)), coffee_white, c="r", label="City 1")
plt.scatter(np.arange(0, len(coffee_minority)), coffee_minority,  c="b", label="City 2")
plt.legend(loc="best")
plt.xlabel("Zip Code")
plt.ylabel("Bench Count")
plt.title("Bench Count in City 1 vs. City 2")
plt.show()

# %%
# Run 2-Sample T-Test
stats.ttest_ind(benches_city_1, benches_city_2, equal_var=False)
# Out:
# Ttest_indResult(statistic=6.3644693126465697, pvalue=8.0393711719628596e-09)
